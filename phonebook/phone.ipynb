# %%
import pandas as pd

phonedata = pd.read_csv('phonedata.csv', sep=',')

phonedata.describe()
# Out:
#        transaction no.  Age (yrs)  length of call (sec)
# count        59.000000  59.000000             59.000000
# mean        527.932203  35.237288             60.728814
# std         290.896288  11.020888             39.472745
# min           9.000000  19.000000              4.000000
# 25%         276.000000  26.000000             38.000000
# 50%         514.000000  34.000000             51.000000
# 75%         752.000000  43.000000             79.500000
# max         998.000000  61.000000            240.000000

# %%
phonedata.head()
# Out:
#    transaction no.     tel.no gender marital status  Age (yrs) time of call  \
# 0                9  077-11180      F        married         22     11:28a.m
# 1               30  077-08743      M        married         36     11:18p.m
# 2               60  077-11180      F        married         22      8:28a.m
# 3               69  077-67293      M        married         26      2:49p.m
# 4               81  077-45678      M         single         38     10:16a.m
#
#    length of call (sec)
# 0                    83
# 1                    38
# 2                    80
# 3                    44
# 4                    79

# %%
# quick description of the data, in particular the
# total number of rows, and each attribute’s type and number of non-null values

 phonedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   transaction no.       59 non-null     int64
#  1   tel.no                59 non-null     object
#  2   gender                59 non-null     object
#  3   marital status        59 non-null     object
#  4   Age (yrs)             59 non-null     int64
#  5   time of call          59 non-null     object
#  6   length of call (sec)  59 non-null     int64
# dtypes: int64(3), object(4)
# memory usage: 3.4+ KB

# %%
# Plot the attributes on a histogram
# %matplotlib inline
import matplotlib.pyplot as plt
phonedata.hist(bins=50, figsize = (20,15))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
from sklearn.model_selection import train_test_split

# Creating target and input classes
X = phonedata.drop(columns=['transaction no.'])
y = phonedata['length of call (sec)'].values
# Out:
# array([83, 38, 80, 44, 79])
